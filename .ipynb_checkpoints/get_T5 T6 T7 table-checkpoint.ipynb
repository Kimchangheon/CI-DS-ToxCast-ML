# %% [markdown]
# # T5

# %%
import pandas as pd

# %%
assays = pd.read_csv("31assays_name.csv")
selected_assay_list = list(assays['Assay Name'])
selected_assay_list.remove('TOX21_NFkB_BLA_agonist_ratio')
# selected_assay_list = ['TOX21_AhR_LUC_Agonist', 'TOX21_Aromatase_Inhibition', 'TOX21_VDR_BLA_agonist_ratio', 'TOX21_VDR_BLA_antagonist_ratio', 'TOX21_AR_BLA_Agonist_ratio', 'TOX21_AR_BLA_Antagonist_ratio', 'TOX21_AR_LUC_MDAKB2_Agonist', 'TOX21_p53_BLA_p1_ratio', 'TOX21_p53_BLA_p2_ratio', 'TOX21_p53_BLA_p3_ratio', 'TOX21_p53_BLA_p4_ratio', 'TOX21_p53_BLA_p5_ratio', 'TOX21_HSE_BLA_agonist_ratio', 'TOX21_ELG1_LUC_Agonist', 'TOX21_ERa_BLA_Agonist_ratio', 'TOX21_ERa_BLA_Antagonist_ratio', 'TOX21_ESRE_BLA_ratio', 'TOX21_FXR_BLA_agonist_ratio', 'TOX21_FXR_BLA_antagonist_ratio', 'TOX21_GR_BLA_Agonist_ratio', 'TOX21_GR_BLA_Antagonist_ratio', 'TOX21_NFkB_BLA_agonist_ratio', 'TOX21_ARE_BLA_agonist_ratio', 'TOX21_TR_LUC_GH3_Agonist', 'TOX21_TR_LUC_GH3_Antagonist', 'TOX21_PPARg_BLA_Agonist_ratio', 'TOX21_PPARd_BLA_agonist_ratio', 'TOX21_PPARd_BLA_antagonist_ratio', 'TOX21_PPARg_BLA_antagonist_ratio']
# selected_assay_list2 = ['NVS_ADME_hCYP1A2' , 'NVS_ADME_hCYP2B6' , 'NCCT_TPO_AUR_dn']
# selected_assay_list += selected_assay_list2

# %%
len(selected_assay_list)
# Out:
# 31

# %%
metric_list = ['valid_AUC','valid_AUC_PR','valid_Recall','valid_F1',
               
               'valid_AUC_tuned','valid_AUC_PR_tuned','valid_Recall_tuned','valid_F1_tuned',
               
              'test_AUC','test_AUC_PR','test_Recall','test_F1',
               
               'test_AUC_tuned','test_AUC_PR_tuned','test_Recall_tuned','test_F1_tuned']

# %%
import pandas as pd
T5 = pd.DataFrame(columns =metric_list, index = selected_assay_list)

# %%
base_ismorehighthan_tuned1 = []
base_ismorehighthan_tuned2 = []
for a in selected_assay_list : 
    result_df = pd.read_csv('./31assays/performance/performance'+a+'.csv').iloc[:,1:]
    
    
    #if base_f1 > tuned_f1 
    if result_df.iloc[0,2] >= result_df.iloc[1,2] : 
        result_df.iloc[1,:] = result_df.iloc[0,:]
        base_ismorehighthan_tuned1.append(a)
    if result_df.iloc[2,2] >= result_df.iloc[3,2] : 
        result_df.iloc[3,:] = result_df.iloc[2,:]    
        base_ismorehighthan_tuned2.append(a)

#     TF_index = result_df.iloc[0,:] > result_df.iloc[1,:]
#     result_df.iloc[1,:][TF_index] = result_df.iloc[0,:]
    
#     TF_index = result_df.iloc[2,:] > result_df.iloc[3,:]
#     result_df.iloc[3,:][TF_index] = result_df.iloc[2,:]
    
    T5.loc[a,:] = result_df.to_numpy().flatten()

# %%
set1 = set(base_ismorehighthan_tuned1 )
set2 = set(base_ismorehighthan_tuned2 )
set3 =(set1.intersection(set2))

# %%
list(set3)
# Out:
# ['TOX21_p53_BLA_p3_ratio',
#  'TOX21_p53_BLA_p2_ratio',
#  'TOX21_PPARg_BLA_antagonist_ratio',
#  'TOX21_AR_LUC_MDAKB2_Agonist',
#  'TOX21_FXR_BLA_antagonist_ratio',
#  'TOX21_VDR_BLA_antagonist_ratio',
#  'TOX21_GR_BLA_Antagonist_ratio',
#  'TOX21_PPARg_BLA_Agonist_ratio',
#  'TOX21_TR_LUC_GH3_Agonist',
#  'TOX21_GR_BLA_Agonist_ratio',
#  'TOX21_PPARd_BLA_agonist_ratio',
#  'TOX21_AhR_LUC_Agonist',
#  'TOX21_ELG1_LUC_Agonist',
#  'NVS_ADME_hCYP2B6',
#  'TOX21_ESRE_BLA_ratio',
#  'TOX21_TR_LUC_GH3_Antagonist',
#  'TOX21_VDR_BLA_agonist_ratio',
#  'NVS_ADME_hCYP1A2']

# %%
T5
# Out:
#                                  valid_AUC valid_AUC_PR valid_Recall  \
# TOX21_VDR_BLA_agonist_ratio       0.645364     0.019288          0.0
# TOX21_VDR_BLA_antagonist_ratio    0.866679     0.143898     0.116667
# TOX21_HSE_BLA_agonist_ratio       0.719451     0.122679     0.142758
# TOX21_ESRE_BLA_ratio              0.699909     0.296016        0.225
# TOX21_FXR_BLA_agonist_ratio       0.646814     0.106447          0.0
# TOX21_FXR_BLA_antagonist_ratio    0.727764      0.17217     0.161613
# TOX21_ARE_BLA_agonist_ratio        0.69375     0.225317     0.281548
# TOX21_PPARd_BLA_agonist_ratio     0.745852      0.20519     0.216667
# TOX21_PPARd_BLA_antagonist_ratio  0.632952     0.085331     0.104762
# TOX21_PPARg_BLA_antagonist_ratio  0.823959     0.213845     0.235001
# TOX21_ELG1_LUC_Agonist             0.71471     0.088764     0.070952
# TOX21_AhR_LUC_Agonist             0.835154     0.222706     0.305146
# TOX21_Aromatase_Inhibition        0.724327     0.181336     0.208699
# TOX21_AR_BLA_Agonist_ratio        0.831663     0.543826     0.544824
# TOX21_AR_BLA_Antagonist_ratio      0.73146     0.222257     0.251455
# TOX21_AR_LUC_MDAKB2_Agonist       0.796488     0.526214     0.489203
# TOX21_p53_BLA_p1_ratio            0.796796     0.155907     0.186566
# TOX21_p53_BLA_p2_ratio            0.674437     0.131604     0.148976
# TOX21_p53_BLA_p3_ratio            0.675606     0.114356     0.147245
# TOX21_p53_BLA_p4_ratio            0.668989     0.122007     0.104269
# TOX21_p53_BLA_p5_ratio            0.633418     0.099118     0.089422
# TOX21_ERa_BLA_Agonist_ratio        0.76953     0.386346     0.352361
# TOX21_ERa_BLA_Antagonist_ratio    0.702239     0.147494     0.160732
# TOX21_GR_BLA_Agonist_ratio        0.854663     0.580274     0.595192
# TOX21_GR_BLA_Antagonist_ratio     0.820447     0.413261      0.38487
# TOX21_TR_LUC_GH3_Agonist          0.512958     0.197085      0.18881
# TOX21_TR_LUC_GH3_Antagonist       0.728439     0.196179     0.216613
# TOX21_PPARg_BLA_Agonist_ratio     0.881413      0.28333     0.193692
# NVS_ADME_hCYP2B6                  0.752961     0.818059       0.9175
# NVS_ADME_hCYP1A2                  0.633242     0.720204     0.751169
# NCCT_TPO_AUR_dn                   0.792425     0.747943     0.659739
#
#                                   valid_F1 valid_AUC_tuned valid_AUC_PR_tuned  \
# TOX21_VDR_BLA_agonist_ratio            0.0        0.645364           0.019288
# TOX21_VDR_BLA_antagonist_ratio    0.088889        0.866679           0.143898
# TOX21_HSE_BLA_agonist_ratio       0.169571        0.748393           0.118079
# TOX21_ESRE_BLA_ratio              0.294545        0.699909           0.296016
# TOX21_FXR_BLA_agonist_ratio            0.0        0.708769           0.057256
# TOX21_FXR_BLA_antagonist_ratio    0.193951        0.727764            0.17217
# TOX21_ARE_BLA_agonist_ratio       0.258207        0.700769           0.228168
# TOX21_PPARd_BLA_agonist_ratio     0.224444        0.745852            0.20519
# TOX21_PPARd_BLA_antagonist_ratio  0.131089        0.666246           0.089152
# TOX21_PPARg_BLA_antagonist_ratio  0.254366        0.823959           0.213845
# TOX21_ELG1_LUC_Agonist            0.108333         0.71471           0.088764
# TOX21_AhR_LUC_Agonist              0.26616        0.835154           0.222706
# TOX21_Aromatase_Inhibition         0.24659        0.723343           0.189456
# TOX21_AR_BLA_Agonist_ratio         0.57712        0.831663           0.543826
# TOX21_AR_BLA_Antagonist_ratio     0.269369        0.725824           0.238262
# TOX21_AR_LUC_MDAKB2_Agonist       0.542239        0.796488           0.526214
# TOX21_p53_BLA_p1_ratio            0.222708        0.815933           0.179956
# TOX21_p53_BLA_p2_ratio            0.161635        0.674437           0.131604
# TOX21_p53_BLA_p3_ratio            0.173709        0.675606           0.114356
# TOX21_p53_BLA_p4_ratio            0.139312        0.636765           0.106389
# TOX21_p53_BLA_p5_ratio            0.089638         0.61829           0.102805
# TOX21_ERa_BLA_Agonist_ratio       0.393993        0.792089           0.395546
# TOX21_ERa_BLA_Antagonist_ratio    0.194604        0.689412           0.136656
# TOX21_GR_BLA_Agonist_ratio        0.608162        0.854663           0.580274
# TOX21_GR_BLA_Antagonist_ratio      0.43053        0.820447           0.413261
# TOX21_TR_LUC_GH3_Agonist           0.24381        0.512958           0.197085
# TOX21_TR_LUC_GH3_Antagonist       0.235014        0.728439           0.196179
# TOX21_PPARg_BLA_Agonist_ratio     0.271194        0.881413            0.28333
# NVS_ADME_hCYP2B6                  0.799128        0.752961           0.818059
# NVS_ADME_hCYP1A2                  0.672867        0.633242           0.720204
# NCCT_TPO_AUR_dn                   0.675084        0.792425           0.747943
#
#                                  valid_Recall_tuned valid_F1_tuned  test_AUC  \
# TOX21_VDR_BLA_agonist_ratio                     0.0            0.0   0.93188
# TOX21_VDR_BLA_antagonist_ratio             0.116667       0.088889  0.991587
# TOX21_HSE_BLA_agonist_ratio                0.160258       0.184029  0.846121
# TOX21_ESRE_BLA_ratio                          0.225       0.294545  0.936845
# TOX21_FXR_BLA_agonist_ratio                     0.2       0.116667  0.899183
# TOX21_FXR_BLA_antagonist_ratio             0.161613       0.193951  0.661528
# TOX21_ARE_BLA_agonist_ratio                0.318128       0.276244  0.744316
# TOX21_PPARd_BLA_agonist_ratio              0.216667       0.224444  0.772458
# TOX21_PPARd_BLA_antagonist_ratio           0.119048        0.14624  0.832817
# TOX21_PPARg_BLA_antagonist_ratio           0.235001       0.254366  0.784274
# TOX21_ELG1_LUC_Agonist                     0.070952       0.108333  0.980817
# TOX21_AhR_LUC_Agonist                      0.305146        0.26616  0.829251
# TOX21_Aromatase_Inhibition                 0.223699       0.264306  0.726008
# TOX21_AR_BLA_Agonist_ratio                 0.544824        0.57712  0.888448
# TOX21_AR_BLA_Antagonist_ratio              0.257274       0.267156  0.609038
# TOX21_AR_LUC_MDAKB2_Agonist                0.489203       0.542239  0.823428
# TOX21_p53_BLA_p1_ratio                     0.202247       0.231228  0.757916
# TOX21_p53_BLA_p2_ratio                     0.148976       0.161635  0.729659
# TOX21_p53_BLA_p3_ratio                     0.147245       0.173709  0.702088
# TOX21_p53_BLA_p4_ratio                     0.164489       0.164873  0.672655
# TOX21_p53_BLA_p5_ratio                     0.089971       0.106605   0.64795
# TOX21_ERa_BLA_Agonist_ratio                0.359504       0.428341  0.726896
# TOX21_ERa_BLA_Antagonist_ratio             0.166515       0.179068   0.74302
# TOX21_GR_BLA_Agonist_ratio                 0.595192       0.608162  0.861336
# TOX21_GR_BLA_Antagonist_ratio               0.38487        0.43053  0.903601
# TOX21_TR_LUC_GH3_Agonist                    0.18881        0.24381  0.589807
# TOX21_TR_LUC_GH3_Antagonist                0.216613       0.235014  0.803797
# TOX21_PPARg_BLA_Agonist_ratio              0.193692       0.271194  0.908353
# NVS_ADME_hCYP2B6                             0.9175       0.799128  0.770833
# NVS_ADME_hCYP1A2                           0.751169       0.672867    0.5375
# NCCT_TPO_AUR_dn                            0.659739       0.675084  0.653548
#
#                                  test_AUC_PR test_Recall   test_F1  \
# TOX21_VDR_BLA_agonist_ratio         0.015385         0.0       0.0
# TOX21_VDR_BLA_antagonist_ratio      0.188393         0.0       0.0
# TOX21_HSE_BLA_agonist_ratio         0.185605        0.25  0.307692
# TOX21_ESRE_BLA_ratio                 0.53417         0.0       0.0
# TOX21_FXR_BLA_agonist_ratio         0.009615         0.0       0.0
# TOX21_FXR_BLA_antagonist_ratio      0.053422    0.153846  0.181818
# TOX21_ARE_BLA_agonist_ratio         0.314329    0.342857  0.347826
# TOX21_PPARd_BLA_agonist_ratio       0.029689         0.0       0.0
# TOX21_PPARd_BLA_antagonist_ratio    0.193188       0.125  0.166667
# TOX21_PPARg_BLA_antagonist_ratio    0.189074    0.238095   0.30303
# TOX21_ELG1_LUC_Agonist              0.660326         0.6  0.666667
# TOX21_AhR_LUC_Agonist               0.160761      0.1875  0.162162
# TOX21_Aromatase_Inhibition          0.092299    0.176471       0.2
# TOX21_AR_BLA_Agonist_ratio          0.614611         0.6  0.588235
# TOX21_AR_BLA_Antagonist_ratio       0.189769         0.2  0.235294
# TOX21_AR_LUC_MDAKB2_Agonist         0.608484    0.580645       0.6
# TOX21_p53_BLA_p1_ratio              0.056807         0.0       0.0
# TOX21_p53_BLA_p2_ratio               0.32614    0.347826       0.4
# TOX21_p53_BLA_p3_ratio              0.089677    0.157895    0.1875
# TOX21_p53_BLA_p4_ratio              0.097292    0.176471  0.214286
# TOX21_p53_BLA_p5_ratio              0.086417    0.117647      0.16
# TOX21_ERa_BLA_Agonist_ratio         0.271717    0.235294  0.307692
# TOX21_ERa_BLA_Antagonist_ratio      0.179695    0.190476  0.216216
# TOX21_GR_BLA_Agonist_ratio          0.713604    0.692308  0.692308
# TOX21_GR_BLA_Antagonist_ratio       0.536398         0.5  0.545455
# TOX21_TR_LUC_GH3_Agonist            0.336335    0.333333       0.5
# TOX21_TR_LUC_GH3_Antagonist         0.253888    0.285714  0.301075
# TOX21_PPARg_BLA_Agonist_ratio       0.397265    0.363636  0.444444
# NVS_ADME_hCYP2B6                    0.848233       0.875  0.823529
# NVS_ADME_hCYP1A2                    0.651916         0.3       0.4
# NCCT_TPO_AUR_dn                     0.630395        0.68  0.596491
#
#                                  test_AUC_tuned test_AUC_PR_tuned  \
# TOX21_VDR_BLA_agonist_ratio             0.93188          0.015385
# TOX21_VDR_BLA_antagonist_ratio         0.991587          0.188393
# TOX21_HSE_BLA_agonist_ratio            0.846121          0.185605
# TOX21_ESRE_BLA_ratio                   0.936845           0.53417
# TOX21_FXR_BLA_agonist_ratio            0.899183          0.009615
# TOX21_FXR_BLA_antagonist_ratio         0.661528          0.053422
# TOX21_ARE_BLA_agonist_ratio            0.744316          0.314329
# TOX21_PPARd_BLA_agonist_ratio          0.772458          0.029689
# TOX21_PPARd_BLA_antagonist_ratio       0.832817          0.193188
# TOX21_PPARg_BLA_antagonist_ratio       0.784274          0.189074
# TOX21_ELG1_LUC_Agonist                 0.980817          0.660326
# TOX21_AhR_LUC_Agonist                  0.829251          0.160761
# TOX21_Aromatase_Inhibition             0.726008          0.092299
# TOX21_AR_BLA_Agonist_ratio             0.900662          0.648619
# TOX21_AR_BLA_Antagonist_ratio          0.620514          0.191455
# TOX21_AR_LUC_MDAKB2_Agonist            0.823428          0.608484
# TOX21_p53_BLA_p1_ratio                 0.792986          0.059637
# TOX21_p53_BLA_p2_ratio                 0.729659           0.32614
# TOX21_p53_BLA_p3_ratio                 0.702088          0.089677
# TOX21_p53_BLA_p4_ratio                 0.672655          0.097292
# TOX21_p53_BLA_p5_ratio                  0.64795          0.086417
# TOX21_ERa_BLA_Agonist_ratio            0.726896          0.271717
# TOX21_ERa_BLA_Antagonist_ratio         0.663887          0.241306
# TOX21_GR_BLA_Agonist_ratio             0.861336          0.713604
# TOX21_GR_BLA_Antagonist_ratio          0.903601          0.536398
# TOX21_TR_LUC_GH3_Agonist               0.589807          0.336335
# TOX21_TR_LUC_GH3_Antagonist            0.803797          0.253888
# TOX21_PPARg_BLA_Agonist_ratio          0.908353          0.397265
# NVS_ADME_hCYP2B6                       0.770833          0.848233
# NVS_ADME_hCYP1A2                         0.5375          0.651916
# NCCT_TPO_AUR_dn                        0.681935          0.648443
#
#                                  test_Recall_tuned test_F1_tuned
# TOX21_VDR_BLA_agonist_ratio                    0.0           0.0
# TOX21_VDR_BLA_antagonist_ratio                 0.0           0.0
# TOX21_HSE_BLA_agonist_ratio                   0.25      0.307692
# TOX21_ESRE_BLA_ratio                           0.0           0.0
# TOX21_FXR_BLA_agonist_ratio                    0.0           0.0
# TOX21_FXR_BLA_antagonist_ratio            0.153846      0.181818
# TOX21_ARE_BLA_agonist_ratio               0.342857      0.347826
# TOX21_PPARd_BLA_agonist_ratio                  0.0           0.0
# TOX21_PPARd_BLA_antagonist_ratio             0.125      0.166667
# TOX21_PPARg_BLA_antagonist_ratio          0.238095       0.30303
# TOX21_ELG1_LUC_Agonist                         0.6      0.666667
# TOX21_AhR_LUC_Agonist                       0.1875      0.162162
# TOX21_Aromatase_Inhibition                0.176471           0.2
# TOX21_AR_BLA_Agonist_ratio                    0.64      0.680851
# TOX21_AR_BLA_Antagonist_ratio                0.225      0.257143
# TOX21_AR_LUC_MDAKB2_Agonist               0.580645           0.6
# TOX21_p53_BLA_p1_ratio                    0.090909      0.111111
# TOX21_p53_BLA_p2_ratio                    0.347826           0.4
# TOX21_p53_BLA_p3_ratio                    0.157895        0.1875
# TOX21_p53_BLA_p4_ratio                    0.176471      0.214286
# TOX21_p53_BLA_p5_ratio                    0.117647          0.16
# TOX21_ERa_BLA_Agonist_ratio               0.235294      0.307692
# TOX21_ERa_BLA_Antagonist_ratio            0.285714      0.315789
# TOX21_GR_BLA_Agonist_ratio                0.692308      0.692308
# TOX21_GR_BLA_Antagonist_ratio                  0.5      0.545455
# TOX21_TR_LUC_GH3_Agonist                  0.333333           0.5
# TOX21_TR_LUC_GH3_Antagonist               0.285714      0.301075
# TOX21_PPARg_BLA_Agonist_ratio             0.363636      0.444444
# NVS_ADME_hCYP2B6                             0.875      0.823529
# NVS_ADME_hCYP1A2                               0.3           0.4
# NCCT_TPO_AUR_dn                               0.72       0.62069

# %%
T5.to_csv("T5.csv")

# %% [markdown]
# # T6

# %% [markdown]
# # T7

# %%
import pandas as pd

T5 = pd.read_csv("T5.csv")

T7 = pd.DataFrame(columns =["valid_AUC","valid_AUC_PR","valid_Recall","valid_F1",
                            "test_AUC","test_AUC_PR","test_Recall","test_F1"], 
                  index = ["CI","DS"])
T7_tuned = pd.DataFrame(columns =['valid_AUC_tuned','valid_AUC_PR_tuned','valid_Recall_tuned','valid_F1_tuned',
                                  'test_AUC_tuned','test_AUC_PR_tuned','test_Recall_tuned','test_F1_tuned'], 
                  index = ["CI","DS"])

# %%
CI_df = T5[:28]
DS_df = T5[28:]

# %%
T7
# Out:
#    valid_AUC valid_AUC_PR valid_Recall valid_F1 test_AUC test_AUC_PR  \
# CI       NaN          NaN          NaN      NaN      NaN         NaN
# DS       NaN          NaN          NaN      NaN      NaN         NaN
#
#    test_Recall test_F1
# CI         NaN     NaN
# DS         NaN     NaN

# %%
T7_tuned
# Out:
#    valid_AUC_tuned valid_AUC_PR_tuned valid_Recall_tuned valid_F1_tuned  \
# CI             NaN                NaN                NaN            NaN
# DS             NaN                NaN                NaN            NaN
#
#    test_AUC_tuned test_AUC_PR_tuned test_Recall_tuned test_F1_tuned
# CI            NaN               NaN               NaN           NaN
# DS            NaN               NaN               NaN           NaN

# %%
CI_df.mean()
# Out:
# /var/folders/34/q4vcf0710b9cm75lplc7sx2w0000gn/T/ipykernel_16512/2440153901.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   CI_df.mean()
# valid_AUC             0.734115
# valid_AUC_PR          0.221509
# valid_Recall          0.218680
# valid_F1              0.242471
# valid_AUC_tuned       0.737905
# valid_AUC_PR_tuned    0.221062
# valid_Recall_tuned    0.232200
# valid_F1_tuned        0.251388
# test_AUC              0.796610
# test_AUC_PR           0.263727
# test_Recall           0.244822
# test_F1               0.276013
# test_AUC_tuned        0.795882
# test_AUC_PR_tuned     0.267303
# test_Recall_tuned     0.253791
# test_F1_tuned         0.287626
# dtype: float64

# %%
T7.loc["CI",:] = CI_df.mean()
T7.loc["DS",:] = DS_df.mean()
# Out:
# /var/folders/34/q4vcf0710b9cm75lplc7sx2w0000gn/T/ipykernel_16512/283940032.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   T7.loc["CI",:] = CI_df.mean()
# /var/folders/34/q4vcf0710b9cm75lplc7sx2w0000gn/T/ipykernel_16512/283940032.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   T7.loc["DS",:] = DS_df.mean()

# %%
T7_tuned.loc["CI",:] = CI_df.mean()
T7_tuned.loc["DS",:] = DS_df.mean()
# Out:
# /var/folders/34/q4vcf0710b9cm75lplc7sx2w0000gn/T/ipykernel_16512/3826891490.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   T7_tuned.loc["CI",:] = CI_df.mean()
# /var/folders/34/q4vcf0710b9cm75lplc7sx2w0000gn/T/ipykernel_16512/3826891490.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   T7_tuned.loc["DS",:] = DS_df.mean()

# %%
T7.index.name = 'base model'
T7
# Out:
#            valid_AUC valid_AUC_PR valid_Recall  valid_F1  test_AUC  \
# base model
# CI          0.734115     0.221509      0.21868  0.242471   0.79661
# DS           0.72621     0.762069     0.776136  0.715693  0.653961
#
#            test_AUC_PR test_Recall   test_F1
# base model
# CI            0.263727    0.244822  0.276013
# DS            0.710181    0.618333  0.606674

# %%
T7_tuned.index.name = 'tuned model'
T7_tuned
# Out:
#             valid_AUC_tuned valid_AUC_PR_tuned valid_Recall_tuned  \
# tuned model
# CI                 0.737905           0.221062             0.2322
# DS                  0.72621           0.762069           0.776136
#
#             valid_F1_tuned test_AUC_tuned test_AUC_PR_tuned test_Recall_tuned  \
# tuned model
# CI                0.251388       0.795882          0.267303          0.253791
# DS                0.715693       0.663423          0.716197          0.631667
#
#             test_F1_tuned
# tuned model
# CI               0.287626
# DS                0.61474

# %%
T7.to_csv("T7_base model.csv")
T7_tuned.to_csv("T7_tuned model.csv")
