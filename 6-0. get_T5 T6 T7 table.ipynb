# %% [markdown]
# # T5

# %%
import pandas as pd

# %%
assays = pd.read_csv("31assays_name.csv")
selected_assay_list = list(assays['Assay Name'])
selected_assay_list.remove('TOX21_NFkB_BLA_agonist_ratio')
# selected_assay_list = ['TOX21_AhR_LUC_Agonist', 'TOX21_Aromatase_Inhibition', 'TOX21_VDR_BLA_agonist_ratio', 'TOX21_VDR_BLA_antagonist_ratio', 'TOX21_AR_BLA_Agonist_ratio', 'TOX21_AR_BLA_Antagonist_ratio', 'TOX21_AR_LUC_MDAKB2_Agonist', 'TOX21_p53_BLA_p1_ratio', 'TOX21_p53_BLA_p2_ratio', 'TOX21_p53_BLA_p3_ratio', 'TOX21_p53_BLA_p4_ratio', 'TOX21_p53_BLA_p5_ratio', 'TOX21_HSE_BLA_agonist_ratio', 'TOX21_ELG1_LUC_Agonist', 'TOX21_ERa_BLA_Agonist_ratio', 'TOX21_ERa_BLA_Antagonist_ratio', 'TOX21_ESRE_BLA_ratio', 'TOX21_FXR_BLA_agonist_ratio', 'TOX21_FXR_BLA_antagonist_ratio', 'TOX21_GR_BLA_Agonist_ratio', 'TOX21_GR_BLA_Antagonist_ratio', 'TOX21_NFkB_BLA_agonist_ratio', 'TOX21_ARE_BLA_agonist_ratio', 'TOX21_TR_LUC_GH3_Agonist', 'TOX21_TR_LUC_GH3_Antagonist', 'TOX21_PPARg_BLA_Agonist_ratio', 'TOX21_PPARd_BLA_agonist_ratio', 'TOX21_PPARd_BLA_antagonist_ratio', 'TOX21_PPARg_BLA_antagonist_ratio']
# selected_assay_list2 = ['NVS_ADME_hCYP1A2' , 'NVS_ADME_hCYP2B6' , 'NCCT_TPO_AUR_dn']
# selected_assay_list += selected_assay_list2

# %%
len(selected_assay_list)
# Out:
# 31

# %%
metric_list = ['valid_AUC','valid_AUC_PR','valid_Recall','valid_F1',
               
               'valid_AUC_tuned','valid_AUC_PR_tuned','valid_Recall_tuned','valid_F1_tuned',
               
              'test_AUC','test_AUC_PR','test_Recall','test_F1',
               
               'test_AUC_tuned','test_AUC_PR_tuned','test_Recall_tuned','test_F1_tuned']

# %%
import pandas as pd
T5 = pd.DataFrame(columns =metric_list, index = selected_assay_list)

# %%
a = selected_assay_list[-1]
pd.read_csv('./31assays/performance/performance'+a+'.csv').iloc[:,1:]
# Out:
#         AUC    AUC_PR    Recall        F1
# 0  0.800988  0.763723  0.659996  0.669974
# 1  0.807348  0.770305  0.664194  0.670031
# 2  0.800000  0.725545  0.880000  0.733333
# 3  0.793548  0.738989  0.840000  0.711864

# %%
a = selected_assay_list[-2]
pd.read_csv('./31assays/performance/performance'+a+'.csv').iloc[:,1:]
# Out:
#         AUC    AUC_PR    Recall        F1
# 0  0.616558  0.714538  0.760924  0.685419
# 1  0.610809  0.699600  0.747667  0.682916
# 2  0.637500  0.783608  0.500000  0.588235
# 3  0.662500  0.797477  0.500000  0.666667

# %%
a = selected_assay_list[-3]
pd.read_csv('./31assays/performance/performance'+a+'.csv').iloc[:,1:]
# Out:
#         AUC    AUC_PR    Recall        F1
# 0  0.861868  0.903900  0.909048  0.782650
# 1  0.820966  0.870933  0.897937  0.771111
# 2  0.770833  0.829309  0.625000  0.625000
# 3  0.812500  0.854234  0.750000  0.800000

# %%
base_ismorehighthan_tuned1 = []
base_ismorehighthan_tuned2 = []
for a in selected_assay_list : 
    result_df = pd.read_csv('./31assays/performance/performance'+a+'.csv').iloc[:,1:]
    
    
    #if base_f1 > tuned_f1 
    if result_df.iloc[0,3] >= result_df.iloc[1,3] : 
        result_df.iloc[1,:] = result_df.iloc[0,:]
        base_ismorehighthan_tuned1.append(a)
    if result_df.iloc[2,3] >= result_df.iloc[3,3] : 
        result_df.iloc[3,:] = result_df.iloc[2,:]    
        base_ismorehighthan_tuned2.append(a)

#     TF_index = result_df.iloc[0,:] > result_df.iloc[1,:]
#     result_df.iloc[1,:][TF_index] = result_df.iloc[0,:]
    
#     TF_index = result_df.iloc[2,:] > result_df.iloc[3,:]
#     result_df.iloc[3,:][TF_index] = result_df.iloc[2,:]
    
    T5.loc[a,:] = result_df.to_numpy().flatten()

# %%
set1 = set(base_ismorehighthan_tuned1 )
set2 = set(base_ismorehighthan_tuned2 )
set3 =(set1.intersection(set2))

# %%
set2
# Out:
# {'NCCT_TPO_AUR_dn',
#  'TOX21_ARE_BLA_agonist_ratio',
#  'TOX21_AR_BLA_Agonist_ratio',
#  'TOX21_ELG1_LUC_Agonist',
#  'TOX21_ESRE_BLA_ratio',
#  'TOX21_FXR_BLA_agonist_ratio',
#  'TOX21_FXR_BLA_antagonist_ratio',
#  'TOX21_GR_BLA_Agonist_ratio',
#  'TOX21_HSE_BLA_agonist_ratio',
#  'TOX21_PPARd_BLA_agonist_ratio',
#  'TOX21_PPARd_BLA_antagonist_ratio',
#  'TOX21_TR_LUC_GH3_Antagonist',
#  'TOX21_VDR_BLA_agonist_ratio',
#  'TOX21_VDR_BLA_antagonist_ratio',
#  'TOX21_p53_BLA_p1_ratio',
#  'TOX21_p53_BLA_p2_ratio',
#  'TOX21_p53_BLA_p3_ratio'}

# %%
list(set3)
# Out:
# ['TOX21_VDR_BLA_agonist_ratio',
#  'TOX21_p53_BLA_p3_ratio',
#  'TOX21_ESRE_BLA_ratio',
#  'TOX21_TR_LUC_GH3_Antagonist',
#  'TOX21_p53_BLA_p2_ratio',
#  'TOX21_ELG1_LUC_Agonist',
#  'TOX21_PPARd_BLA_antagonist_ratio',
#  'TOX21_VDR_BLA_antagonist_ratio']

# %%
T5
# Out:
#                                  valid_AUC valid_AUC_PR valid_Recall  \
# TOX21_VDR_BLA_agonist_ratio       0.623869     0.021506          0.0
# TOX21_VDR_BLA_antagonist_ratio    0.786417     0.121387     0.116667
# TOX21_HSE_BLA_agonist_ratio       0.742414     0.113968     0.147619
# TOX21_ESRE_BLA_ratio              0.733948     0.299513        0.225
# TOX21_FXR_BLA_agonist_ratio       0.722509     0.107787          0.0
# TOX21_FXR_BLA_antagonist_ratio    0.724076      0.16537     0.142447
# TOX21_ARE_BLA_agonist_ratio       0.702339     0.233028     0.284055
# TOX21_PPARd_BLA_agonist_ratio     0.743414      0.15927     0.183333
# TOX21_PPARd_BLA_antagonist_ratio  0.654914     0.078148     0.119048
# TOX21_PPARg_BLA_antagonist_ratio  0.832677     0.209104     0.228756
# TOX21_ELG1_LUC_Agonist            0.728134     0.090296     0.070952
# TOX21_AhR_LUC_Agonist             0.833304     0.228687     0.296135
# TOX21_Aromatase_Inhibition        0.725138     0.184807     0.195714
# ...

# %%
T5.to_csv("T5.csv")

# %% [markdown]
# # T6

# %% [markdown]
# # T7

# %%
import pandas as pd

T5 = pd.read_csv("T5_within.csv")

T7 = pd.DataFrame(columns =["valid_AUC","valid_AUC_PR","valid_Recall","valid_F1",
                            "test_AUC","test_AUC_PR","test_Recall","test_F1"], 
                  index = ["CI","DS"])
T7_tuned = pd.DataFrame(columns =['valid_AUC_tuned','valid_AUC_PR_tuned','valid_Recall_tuned','valid_F1_tuned',
                                  'test_AUC_tuned','test_AUC_PR_tuned','test_Recall_tuned','test_F1_tuned'], 
                  index = ["CI","DS"])

# %%
CI_df = T5[:28]
DS_df = T5[28:]

# %%
T7
# Out:
#    valid_AUC valid_AUC_PR valid_Recall valid_F1 test_AUC test_AUC_PR  \
# CI       NaN          NaN          NaN      NaN      NaN         NaN
# DS       NaN          NaN          NaN      NaN      NaN         NaN
#
#    test_Recall test_F1
# CI         NaN     NaN
# DS         NaN     NaN

# %%
T7_tuned
# Out:
#    valid_AUC_tuned valid_AUC_PR_tuned valid_Recall_tuned valid_F1_tuned  \
# CI             NaN                NaN                NaN            NaN
# DS             NaN                NaN                NaN            NaN
#
#    test_AUC_tuned test_AUC_PR_tuned test_Recall_tuned test_F1_tuned
# CI            NaN               NaN               NaN           NaN
# DS            NaN               NaN               NaN           NaN

# %%
CI_df.mean()
# Out:
# /tmp/ipykernel_28589/2440153901.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   CI_df.mean()
# valid_AUC             0.735001
# valid_AUC_PR          0.219120
# valid_Recall          0.217088
# valid_F1              0.240430
# valid_AUC_tuned       0.739098
# valid_AUC_PR_tuned    0.215805
# valid_Recall_tuned    0.234568
# valid_F1_tuned        0.253224
# test_AUC              0.791637
# test_AUC_PR           0.262226
# test_Recall           0.255197
# test_F1               0.294934
# test_AUC_tuned        0.805827
# test_AUC_PR_tuned     0.272781
# test_Recall_tuned     0.271735
# test_F1_tuned         0.312382
# dtype: float64

# %%
T7.loc["CI",:] = CI_df.mean()
T7.loc["DS",:] = DS_df.mean()
# Out:
# /tmp/ipykernel_28589/283940032.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   T7.loc["CI",:] = CI_df.mean()
# /tmp/ipykernel_28589/283940032.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   T7.loc["DS",:] = DS_df.mean()

# %%
T7_tuned.loc["CI",:] = CI_df.mean()
T7_tuned.loc["DS",:] = DS_df.mean()
# Out:
# /tmp/ipykernel_28589/3826891490.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   T7_tuned.loc["CI",:] = CI_df.mean()
# /tmp/ipykernel_28589/3826891490.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   T7_tuned.loc["DS",:] = DS_df.mean()

# %%
T7.index.name = 'base model'
T7
# Out:
#            valid_AUC valid_AUC_PR valid_Recall  valid_F1  test_AUC  \
# base model
# CI          0.735001      0.21912     0.217088   0.24043  0.791637
# DS          0.759805     0.794054     0.776656  0.712681  0.678368
#
#            test_AUC_PR test_Recall   test_F1
# base model
# CI            0.262226    0.255197  0.294934
# DS            0.714242    0.543333  0.534302

# %%
T7_tuned.index.name = 'tuned model'
T7_tuned
# Out:
#             valid_AUC_tuned valid_AUC_PR_tuned valid_Recall_tuned  \
# tuned model
# CI                 0.739098           0.215805           0.234568
# DS                 0.761925           0.796248           0.778055
#
#             valid_F1_tuned test_AUC_tuned test_AUC_PR_tuned test_Recall_tuned  \
# tuned model
# CI                0.253224       0.805827          0.272781          0.271735
# DS                  0.7127       0.701806          0.731528          0.626667
#
#             test_F1_tuned
# tuned model
# CI               0.312382
# DS               0.661286

# %%
T7.to_csv("T7_within_base model.csv")
T7_tuned.to_csv("T7_within_tuned model.csv")
